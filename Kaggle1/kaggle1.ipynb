# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from sklearn.neighbors import NearestNeighbors
from collections import defaultdict
from sklearn.cluster import KMeans
from sklearn.neighbors import KNeighborsClassifier
from sklearn.mixture import GaussianMixture
from sklearn.cluster import DBSCAN
from collections import Counter
from sklearn.preprocessing import StandardScaler
from scipy.fft import fft, ifft
# Out:
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv('C:/Users/richa/Downloads/unsupervised-learning-m2023/Train.csv')
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  8.130500  8.130500  8.160400  8.160300  8.160500  8.145400  8.145400
# 1  1.034900  1.020200  1.020100  1.005200  1.027500  1.020100  1.049500
# 2  5.421700  5.384300  5.362200  5.377000  5.347300  5.391900  5.451800
# 3 -0.009461 -0.009368  0.015046  0.006892  0.008811  0.007001 -0.005710
# 4  0.001915  0.023485  0.014330  0.018045  0.030433  0.029523  0.014217
#
#           7         8         9  ...      6242      6243      6244      6245  \
# 0  8.137600  8.130700  8.115500  ...  7.846600  7.846700  7.802100  7.839200
# 1  0.997440  1.064600  1.020200  ...  1.460400  1.467900  1.461100  1.460600
# 2  5.511100  5.392100  5.421500  ...  5.761100  5.723900  5.671300  5.723800
# 3  0.010574 -0.009296  0.005122  ...  0.020671 -0.006414 -0.004528 -0.003532
# 4  0.030563  0.030531  0.027022  ... -0.015156 -0.004303  0.001816  0.016999
#
#        6246      6247      6248      6249   Sensor  Action_Person
# ...

# %%
train_data = df.drop(['Action_Person'], axis=1)

# %%
# train_data.head()
train_data.shape
# Out:
# (6840, 6251)

# %%
fd = pd.read_csv('C:/Users/richa/Downloads/unsupervised-learning-m2023/Test.csv')
fd.head()
# Out:
#           0         1         2        3         4         5         6  \
# 0 -0.005553 -0.005555 -0.001927  0.00362 -0.000057 -0.016367 -0.000747
# 1 -0.506510 -0.503990 -0.509880 -0.51366 -0.516020 -0.521940 -0.519750
# 2  1.129800  1.299100  1.307800  1.03980  0.574590  0.116000 -0.169270
# 3 -1.000500 -0.993640 -1.015500 -0.95595 -0.971360 -0.986350 -0.926550
# 4 -0.774860 -0.752180 -0.711310 -0.65723 -0.621070 -0.587910 -0.541140
#
#           7         8        9  ...       117       118       119       120  \
# 0 -0.009958 -0.016365 -0.01098  ...  0.025315  0.004389  0.003512  0.004473
# 1 -0.512000 -0.504350 -0.49535  ... -0.502250 -0.506890 -0.507520 -0.502950
# 2 -0.109780 -0.094517 -0.26583  ...  0.503220  0.929130  0.997340  1.140400
# 3 -1.030600 -0.941640 -0.86113  ... -0.882290 -1.045300 -0.897400 -0.941900
# 4 -0.483030 -0.423670 -0.38125  ... -0.507830 -0.466720 -0.427060 -0.388320
#
#         121       122       123       124    Sensor     ID
# ...

# %%
test_data = fd.drop(['Sensor', 'ID'], axis=1)
print(test_data.shape)
ID = fd['ID']
X_test = test_data
# Out:
# (68400, 125)

# %%
test_data.head()
# Out:
#           0         1         2        3         4         5         6  \
# 0 -0.005553 -0.005555 -0.001927  0.00362 -0.000057 -0.016367 -0.000747
# 1 -0.506510 -0.503990 -0.509880 -0.51366 -0.516020 -0.521940 -0.519750
# 2  1.129800  1.299100  1.307800  1.03980  0.574590  0.116000 -0.169270
# 3 -1.000500 -0.993640 -1.015500 -0.95595 -0.971360 -0.986350 -0.926550
# 4 -0.774860 -0.752180 -0.711310 -0.65723 -0.621070 -0.587910 -0.541140
#
#           7         8        9  ...       115       116       117       118  \
# 0 -0.009958 -0.016365 -0.01098  ...  0.003584  0.008056  0.025315  0.004389
# 1 -0.512000 -0.504350 -0.49535  ... -0.463700 -0.486350 -0.502250 -0.506890
# 2 -0.109780 -0.094517 -0.26583  ... -0.466180  0.346540  0.503220  0.929130
# 3 -1.030600 -0.941640 -0.86113  ... -0.896860 -1.067700 -0.882290 -1.045300
# 4 -0.483030 -0.423670 -0.38125  ... -0.585560 -0.547390 -0.507830 -0.466720
#
#         119       120       121       122       123       124
# ...

# %%
# break train_data into chunks of 125 columns
chunk_size = 125

# Calculate the number of chunks
num_chunks = len(train_data.columns) // chunk_size 

# Create an empty list to store the DataFrame chunks
chunks = []

# Split the DataFrame into chunks
for i in range(num_chunks):
    start = i * chunk_size
    end = (i + 1) * chunk_size
    chunk = train_data.iloc[:, start:end]  # Select columns in the range
    chunks.append(chunk)

# %%
print(len(chunks))
# Out:
# 50

# %%
# convert all chunks into numpy arrays
chunks = [np.array(chunk) for chunk in chunks]
# vertically stack chunks
train_data = np.vstack(chunks)
print(train_data.shape)
# convert train_data into a dataframe
# train_data = pd.DataFrame(train_data)
# Out:
# (342000, 125)

# %%
labels = df['Action_Person']
labels.head()
# Out:
# 0    a01_p1
# 1    a01_p1
# 2    a01_p1
# 3    a01_p1
# 4    a01_p1
# Name: Action_Person, dtype: object

# %%
print(labels)
print(labels.shape)
# Out:
# 0       a01_p1
# 1       a01_p1
# 2       a01_p1
# 3       a01_p1
# 4       a01_p1
#          ...
# 6835    a19_p8
# 6836    a19_p8
# 6837    a19_p8
# 6838    a19_p8
# 6839    a19_p8
# Name: Action_Person, Length: 6840, dtype: object
# (6840,)

# %%
labels = np.array(labels)
tot_labels = np.array([])
for i in range(0, 50):
    tot_labels = np.append(tot_labels, labels)
print(tot_labels.shape)
# Out:
# (342000,)

# %%
sensors = df['Sensor']
# make 50 copies of sensors
tot_sensors = np.array([])
for i in range(0, 50):
    tot_sensors = np.append(tot_sensors, sensors)
# print(tot_sensors[:6841])

# %%
train_data_wsens = np.hstack((train_data, tot_sensors[:, None]))
print(train_data_wsens.shape)
# Out:
# (342000, 126)

# %%
# horizontally stack labels with train_data
train_data_wlbls = np.hstack((train_data_wsens, tot_labels[:, None]))
print(train_data_wlbls.shape)
# Out:
# (342000, 127)

# %% [markdown]
# ## this is the final chuncked dataset

# %%
train_data_wlbls = pd.DataFrame(train_data_wlbls)
train_data_wlbls.head(6841)
# Out:
#            0         1         2         3         4         5         6    \
# 0       8.1305    8.1305    8.1604    8.1603    8.1605    8.1454    8.1454
# 1       1.0349    1.0202    1.0201    1.0052    1.0275    1.0201    1.0495
# 2       5.4217    5.3843    5.3622     5.377    5.3473    5.3919    5.4518
# 3    -0.009461 -0.009368  0.015046  0.006892  0.008811  0.007001  -0.00571
# 4     0.001915  0.023485   0.01433  0.018045  0.030433  0.029523  0.014217
# ...        ...       ...       ...       ...       ...       ...       ...
# 6836   0.12146 -0.022782  -0.35188 -0.089085  -0.45311  -0.58224  -0.32209
# 6837   0.63434   0.63286   0.62999   0.62259   0.61296   0.59231   0.58296
# 6838   0.30237   0.30606   0.31623   0.32615    0.3425   0.36523   0.37295
# 6839   0.49851   0.50021   0.49476   0.49836    0.4975   0.50538   0.50871
# 6840    7.9665    7.9516    7.9889    7.9367    7.9365    7.9516    7.9515
#
# ...

# %%
# get all unique sensor values
unique_sensors = np.unique(train_data_wlbls[125])
# store a dataframe for each sensor, key = sensor, value = dataframe, the dataframe contains all rows with that sensor
sensor_dataframes = {}
for sensor in unique_sensors:
    sensor_dataframes[sensor] = train_data_wlbls.loc[train_data_wlbls[125] == sensor]
# print shape of each dataframe

# %%
print(len(sensor_dataframes))
# for sensor in unique_sensors:
#     print(sensor_dataframes[sensor].shape)
sens_clst_map = {}
sens_model_map = {}
# Out:
# 45

# %% [markdown]
# ## apply pre emphasis filter

# %%
alpha = 0.9
def apply_pre_emphasis(time_series, alpha):
    # Initialize an array for the filtered time series
    filtered_series = np.zeros_like(time_series)

    # Apply the pre-emphasis filter
    for i in range(1, len(time_series)):
        filtered_series[i] = time_series[i] - alpha * time_series[i - 1]

    return filtered_series

# %%
def denoise_column(column):
    std_dev = np.std(column)
    threshold = 6 * std_dev
    # Apply FFT to the column
    column_freq_domain = fft(column)
    
    # Calculate the magnitude spectrum
    magnitude_spectrum = np.abs(column_freq_domain)
    
    # Identify noise frequencies using a threshold
    noise_indices = np.where(magnitude_spectrum < threshold)
    
    # Set the magnitudes at noise frequencies to zero
    column_freq_domain[noise_indices] = 0
    
    # Apply IFFT to get the denoised column
    denoised_column = ifft(column_freq_domain)
    #remove complex part
    denoised_column = np.real(denoised_column)
    return denoised_column

# %% [markdown]
# ## training using knn

# %%
# using kmeans
# for sensor in unique_sensors:
#     y_train = sensor_dataframes[sensor][126]
#     X_train = sensor_dataframes[sensor].drop([125, 126], axis=1)
#     kmeans = KMeans(n_clusters=125, random_state=42).fit(X_train)
#     sens_model_map[sensor] = kmeans
#     labels = kmeans.labels_
#     # print(labels)
#     df_cluster = pd.DataFrame({'cluster':labels , 'action_person': y_train})
#     cluster_mapping = df_cluster.groupby('cluster')['action_person'].agg(lambda x:x.value_counts().index[0])
#     # save the cluster mapping for each sensor in a dictionary
#     sens_clst_map[sensor] = cluster_mapping

# using knn
# do the same above steps for training using from sklearn.neighbors import NearestNeighbors
for sensor in unique_sensors:
    y_train = sensor_dataframes[sensor][126]
    X_train = sensor_dataframes[sensor].drop([125, 126], axis=1)
    neigh = NearestNeighbors(n_neighbors=1, radius = 10,metric='minkowski',p=1)
    # use fft to denoise the data for each column in X_train
    for col in X_train.columns:
        X_train[col] = denoise_column(X_train[col])
    neigh.fit(X_train)
    sens_model_map[sensor] = neigh
    distances, indices = neigh.kneighbors(X_train)
    cluster_labels = []
    for i in range(len(X_train)):
        nearest_indices = indices[i]
        nearest_labels = y_train.iloc[nearest_indices].values

        label_counts = Counter(nearest_labels)

        most_common_label = label_counts.most_common(1)[0][0]
        cluster_labels.append(most_common_label)

    df_cluster = pd.DataFrame({'cluster':cluster_labels , 'action_person': y_train})
    cluster_mapping = df_cluster.groupby('cluster')['action_person'].agg(lambda x:x.value_counts().index[0])
    # save the cluster mapping for each sensor in a dictionary
    sens_clst_map[sensor] = cluster_mapping

# %% [markdown]
# ## mapping of action_person to number

# %%
# map action_person to numbers
m = {}
temp = 0

for i in range(1,20):
    for j in range(1,9):
        if len(str(i)) == 1:
            m['a0'+str(i)+'_p'+str(j)] = temp
        else:
            m['a'+str(i)+'_p'+str(j)] = temp
        temp += 1
print(m)
# Out:
# {'a01_p1': 0, 'a01_p2': 1, 'a01_p3': 2, 'a01_p4': 3, 'a01_p5': 4, 'a01_p6': 5, 'a01_p7': 6, 'a01_p8': 7, 'a02_p1': 8, 'a02_p2': 9, 'a02_p3': 10, 'a02_p4': 11, 'a02_p5': 12, 'a02_p6': 13, 'a02_p7': 14, 'a02_p8': 15, 'a03_p1': 16, 'a03_p2': 17, 'a03_p3': 18, 'a03_p4': 19, 'a03_p5': 20, 'a03_p6': 21, 'a03_p7': 22, 'a03_p8': 23, 'a04_p1': 24, 'a04_p2': 25, 'a04_p3': 26, 'a04_p4': 27, 'a04_p5': 28, 'a04_p6': 29, 'a04_p7': 30, 'a04_p8': 31, 'a05_p1': 32, 'a05_p2': 33, 'a05_p3': 34, 'a05_p4': 35, 'a05_p5': 36, 'a05_p6': 37, 'a05_p7': 38, 'a05_p8': 39, 'a06_p1': 40, 'a06_p2': 41, 'a06_p3': 42, 'a06_p4': 43, 'a06_p5': 44, 'a06_p6': 45, 'a06_p7': 46, 'a06_p8': 47, 'a07_p1': 48, 'a07_p2': 49, 'a07_p3': 50, 'a07_p4': 51, 'a07_p5': 52, 'a07_p6': 53, 'a07_p7': 54, 'a07_p8': 55, 'a08_p1': 56, 'a08_p2': 57, 'a08_p3': 58, 'a08_p4': 59, 'a08_p5': 60, 'a08_p6': 61, 'a08_p7': 62, 'a08_p8': 63, 'a09_p1': 64, 'a09_p2': 65, 'a09_p3': 66, 'a09_p4': 67, 'a09_p5': 68, 'a09_p6': 69, 'a09_p7': 70, 'a09_p8': 71,
# ...

# %%
# split test data based on sensor, store in a dictionary where key = sensor, value = dataframe
test_dataframes = {}
for sensor in unique_sensors:
    test_dataframes[sensor] = fd.loc[fd['Sensor'] == sensor]

# %%
# using kmeans
# predict action_person for each sensor
# preds = []
# for sensor in unique_sensors:
#     X_test = test_dataframes[sensor].drop(['Sensor', 'ID'], axis=1)
#     kmeans = sens_model_map[sensor]
#     test_answers = kmeans.predict(X_test)
#     test_answers = [m[sens_clst_map[sensor][i]] for i in test_answers]
#     # output is a dataframe with two columns, ID and TARGET, where TARGET is the predicted action_person
#     output = pd.DataFrame({'ID': test_dataframes[sensor]['ID'], 'TARGET': test_answers})
#     preds.append(output)
# # concatenate all dataframes in preds
# final_output = pd.concat(preds)
# final_output.head()

# using knn
preds = []
for sensor in unique_sensors:
    X_test = test_dataframes[sensor].drop(['Sensor', 'ID'], axis=1)
    neigh = sens_model_map[sensor]
    # apply pre emphasis filter to X_test
    # for column in X_test.columns:
    #     X_test[column] = apply_pre_emphasis(X_test[column], alpha)
    distances, indices = neigh.kneighbors(X_test)
    cluster_labels = []
    for i in range(len(X_test)):
        nearest_indices = indices[i]
        nearest_labels = y_train.iloc[nearest_indices].values

        label_counts = Counter(nearest_labels)

        most_common_label = label_counts.most_common(1)[0][0]
        cluster_labels.append(most_common_label)
    test_answers = [m[sens_clst_map[sensor][i]] for i in cluster_labels]
    # output is a dataframe with two columns, ID and TARGET, where TARGET is the predicted action_person
    output = pd.DataFrame({'ID': test_dataframes[sensor]['ID'], 'TARGET': test_answers})
    preds.append(output)
# concatenate all dataframes in preds
final_output = pd.concat(preds)
final_output.head()
# Out:
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but NearestNeighbors was fitted without feature names
#   warnings.warn(
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but NearestNeighbors was fitted without feature names
#   warnings.warn(
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but NearestNeighbors was fitted without feature names
#   warnings.warn(
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but NearestNeighbors was fitted without feature names
#   warnings.warn(
# c:\Users\richa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:457: UserWarning: X has feature names, but NearestNeighbors was fitted without feature names
# ...

# %%
# write final_output to a csv file
final_output.to_csv('new.csv', index=False)

# %%
# ss = pd.read_csv('new.csv')
# ss.head()

# %% [markdown]
# ## to confirm if we can submit this csv on kaggle, as less submissions were left
# old.csv is assumed to be a csv file generated by the older model

# %%
ss = pd.read_csv('old.csv')
ss.head()
# Out:
#       ID  TARGET
# 0  15138      33
# 1  10818      24
# 2  48798     108
# 3  61713     137
# 4  23283      51

# %%
ss_new = pd.read_csv('new.csv')
for i in range(len(ss)):
    if ss['TARGET'][i] != ss_new['TARGET'][i]:
        print("hello")
        with open('diff.txt', 'a') as f:
            f.write(str(i) + '\n')
    # print(ss['TARGET'][i], ss_new['TARGET'][i], i)
# if there is a diff between old and new, write the index to a text file


#%%
# read the text file diff.txt
with open('diff.txt', 'r') as f:
    lines = f.readlines()
print(len(lines))
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# ...

# %%
# print(ss.head())
# print(ss_new.head())
